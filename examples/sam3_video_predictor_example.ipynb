# %%
# Copyright (c) Meta Platforms, Inc. and affiliates.

# %% [markdown]
# ## Video segmentation and tracking with SAM 3
#
# This notebook demonstrates how to use SAM 3 for interactive video segmentation and dense tracking. It covers the following capabilities:
#
# - **Text prompts**: Using natural language descriptions to segment objects (e.g., "person", "shoe")
# - **Point prompts**: Adding positive/negative clicks to segment and refine objects
#
# We use the terms _segment_ or _mask_ to refer to the model prediction for an object on a single frame, and _masklet_ to refer to the spatio-temporal masks across the entire video.

# %% [markdown]
# # <a target="_blank" href="https://colab.research.google.com/github/facebookresearch/sam3/blob/main/notebooks/sam3_video_predictor_example.ipynb">
# #   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# # </a>

# %%
using_colab = False

# %%
if using_colab:
    import torch
    import torchvision
    print("PyTorch version:", torch.__version__)
    print("Torchvision version:", torchvision.__version__)
    print("CUDA is available:", torch.cuda.is_available())
    import sys
    # !{sys.executable} -m pip install opencv-python matplotlib scikit-learn
    # !{sys.executable} -m pip install 'git+https://github.com/facebookresearch/sam3.git'

# %%
# !nvidia-smi
# Out:
# Tue Jun 23 15:04:38 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 591.86                 Driver Version: 591.86         CUDA Version: 13.1     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                  Driver-Model | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 3090      WDDM  |   00000000:01:00.0  On |                  N/A |
# |  0%   51C    P8             23W /  350W |     533MiB /  24576MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0   N/A  N/A            4604    C+G   ....0.4022.80\msedgewebview2.exe      N/A      |
# |    0   N/A  N/A            6556    C+G   ...ntrolPanel\SystemSettings.exe      N/A      |
# |    0   N/A  N/A            6988    C+G   ...5n1h2txyewy\TextInputHost.exe      N/A      |
# |    0   N/A  N/A            7216    C+G   ...y\StartMenuExperienceHost.exe      N/A      |
# |    0   N/A  N/A            7296    C+G   ..._cw5n1h2txyewy\SearchHost.exe      N/A      |
# |    0   N/A  N/A            7356    C+G   C:\Windows\explorer.exe               N/A      |
# |    0   N/A  N/A            7452    C+G   ...indows\System32\ShellHost.exe      N/A      |
# |    0   N/A  N/A            7732    C+G   ...2txyewy\CrossDeviceResume.exe      N/A      |
# |    0   N/A  N/A           10472    C+G   ....0.4022.80\msedgewebview2.exe      N/A      |
# |    0   N/A  N/A           11324    C+G   ...em32\ApplicationFrameHost.exe      N/A      |
# |    0   N/A  N/A           11716    C+G   ...App_cw5n1h2txyewy\LockApp.exe      N/A      |
# |    0   N/A  N/A           12660    C+G   ...t\Edge\Application\msedge.exe      N/A      |
# |    0   N/A  N/A           13040    C+G   ...xyewy\ShellExperienceHost.exe      N/A      |
# |    0   N/A  N/A           13796    C+G   ...Chrome\Application\chrome.exe      N/A      |
# |    0   N/A  N/A           15936    C+G   ...ms\Microsoft VS Code\Code.exe      N/A      |
# +-----------------------------------------------------------------------------------------+

# %% [markdown]
# ## Set-up
#
# In this example, we allow running inference either on a single GPU or multiple GPUs.

# %%
import os
import sam3
import torch

sam3_root = os.path.join(os.path.dirname(sam3.__file__), "..")

# use all available GPUs on the machine
gpus_to_use = range(torch.cuda.device_count())
# # use only a single GPU
# gpus_to_use = [torch.cuda.current_device()]
# Out:
# C:\Users\ait44\sam3\sam3\model_builder.py:8: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# c:\Users\ait44\anaconda3\envs\sam3\Lib\site-packages\timm\models\layers\__init__.py:49: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)

# %%
from sam3.model_builder import build_sam3_video_predictor

predictor = build_sam3_video_predictor(gpus_to_use=gpus_to_use)
# Out:
# INFO 2026-06-23 15:04:49,680 12332 sam3_video_predictor.py: 109: using the following GPU IDs: [0]
# INFO 2026-06-23 15:04:49,767 12332 sam3_video_predictor.py: 125:
#
#
# 	*** START loading model on all ranks ***
#
#
# INFO 2026-06-23 15:04:49,768 12332 sam3_video_predictor.py: 127: loading model on rank=0 with world_size=1 -- this could take a while ...
# INFO 2026-06-23 15:04:55,802 12332 sam3_video_base.py: 348: setting max_num_objects=10000 and num_obj_for_compile=16
# INFO 2026-06-23 15:05:02,697 12332 sam3_video_predictor.py: 129: loading model on rank=0 with world_size=1 -- DONE locally
# INFO 2026-06-23 15:05:02,697 12332 sam3_video_predictor.py: 140:
#
#
# 	*** DONE loading model on all ranks ***

# %% [markdown]
# #### Inference and visualization utils

# %%
import glob
import os

import cv2
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image
from sam3.visualization_utils import (
    load_frame,
    prepare_masks_for_visualization,
    visualize_formatted_frame_output,
)

# font size for axes titles
plt.rcParams["axes.titlesize"] = 12
plt.rcParams["figure.titlesize"] = 12


def propagate_in_video(predictor, session_id):
    # we will just propagate from frame 0 to the end of the video
    outputs_per_frame = {}
    for response in predictor.handle_stream_request(
        request=dict(
            type="propagate_in_video",
            session_id=session_id,
        )
    ):
        outputs_per_frame[response["frame_index"]] = response["outputs"]

    return outputs_per_frame


def abs_to_rel_coords(coords, IMG_WIDTH, IMG_HEIGHT, coord_type="point"):
    """Convert absolute coordinates to relative coordinates (0-1 range)

    Args:
        coords: List of coordinates
        coord_type: 'point' for [x, y] or 'box' for [x, y, w, h]
    """
    if coord_type == "point":
        return [[x / IMG_WIDTH, y / IMG_HEIGHT] for x, y in coords]
    elif coord_type == "box":
        return [
            [x / IMG_WIDTH, y / IMG_HEIGHT, w / IMG_WIDTH, h / IMG_HEIGHT]
            for x, y, w, h in coords
        ]
    else:
        raise ValueError(f"Unknown coord_type: {coord_type}")

# %% [markdown]
# ### Loading an example video
#
# We assume that the video is stored as either **a list of JPEG frames with filenames like `<frame_index>.jpg`** or **an MP4 video**.
#
# Note that you can extract their JPEG frames using ffmpeg (https://ffmpeg.org/) as follows:
# ```
# ffmpeg -i <your_video>.mp4 -q:v 2 -start_number 0 <output_dir>/'%05d.jpg'
# ```
# where `-q:v` generates high-quality JPEG frames and `-start_number 0` asks ffmpeg to start the JPEG file from `00000.jpg`.

# %%
# "video_path" needs to be either a JPEG folder or a MP4 video file
video_path = f"{sam3_root}/assets/videos/bedroom.mp4"

# %%
# load "video_frames_for_vis" for visualization purposes (they are not used by the model)
if isinstance(video_path, str) and video_path.endswith(".mp4"):
    cap = cv2.VideoCapture(video_path)
    video_frames_for_vis = []
    while True:
        ret, frame = cap.read()
        if not ret:
            break
        video_frames_for_vis.append(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))
    cap.release()
else:
    video_frames_for_vis = glob.glob(os.path.join(video_path, "*.jpg"))
    try:
        # integer sort instead of string sort (so that e.g. "2.jpg" is before "11.jpg")
        video_frames_for_vis.sort(
            key=lambda p: int(os.path.splitext(os.path.basename(p))[0])
        )
    except ValueError:
        # fallback to lexicographic sort if the format is not "<frame_index>.jpg"
        print(
            f'frame names are not in "<frame_index>.jpg" format: {video_frames_for_vis[:5]=}, '
            f"falling back to lexicographic sort."
        )
        video_frames_for_vis.sort()

# %% [markdown]
# ### Opening an inference session on this video
#
# SAM 3 requires stateful inference for interactive video segmentation, so we need to initialize an **inference session** on this video.
#
# During initialization, it loads all the video frames and stores their pixels in the session state.

# %%
response = predictor.handle_request(
    request=dict(
        type="start_session",
        resource_path=video_path,
    )
)
session_id = response["session_id"]
# Out:
# frame loading (OpenCV) [rank=0]: 100%|██████████| 200/200 [00:00<00:00, 376.34it/s]
# INFO 2026-06-23 15:08:03,619 12332 sam3_base_predictor.py: 150: started new session a9f523b6-656c-4117-aaa6-22cb02144a80

# %% [markdown]
# ### Video promptable concept segmentation with text
#
# Using SAM 3 you can describe objects using natural language, and the model will automatically detect and track all instances of that object throughout the video.
#
# In the example below, we add a text prompt on frame 0 and propagation throughout the video. Here we use the text prompt "person" to detect all people in the video. SAM 3 will automatically identify multiple person instances and assign each a unique object ID.
#
# Note that the first call might be slower due to setting up buffers. **You can rerun all the cells below when measuring speed.**

# %%
# note: in case you already ran one text prompt and now want to switch to another text prompt
# it's required to reset the session first (otherwise the results would be wrong)
_ = predictor.handle_request(
    request=dict(
        type="reset_session",
        session_id=session_id,
    )
)

# %%
prompt_text_str = "person"
frame_idx = 0  # add a text prompt on frame 0
response = predictor.handle_request(
    request=dict(
        type="add_prompt",
        session_id=session_id,
        frame_index=frame_idx,
        text=prompt_text_str,
    )
)
out = response["outputs"]

plt.close("all")
visualize_formatted_frame_output(
    frame_idx,
    video_frames_for_vis,
    outputs_list=[prepare_masks_for_visualization({frame_idx: out})],
    titles=["SAM 3 Dense Tracking outputs"],
    figsize=(6, 4),
)

# %%
# now we propagate the outputs from frame 0 to the end of the video and collect all outputs
outputs_per_frame = propagate_in_video(predictor, session_id)

# finally, we reformat the outputs for visualization and plot the outputs every 60 frames
outputs_per_frame = prepare_masks_for_visualization(outputs_per_frame)

vis_frame_stride = 60
plt.close("all")
for frame_idx in range(0, len(outputs_per_frame), vis_frame_stride):
    visualize_formatted_frame_output(
        frame_idx,
        video_frames_for_vis,
        outputs_list=[outputs_per_frame],
        titles=["SAM 3 Dense Tracking outputs"],
        figsize=(6, 4),
    )
# Out:
# propagate_in_video:   0%|          | 0/200 [00:00<?, ?it/s]
# propagate_in_video: 0it [00:00, ?it/s]
# INFO 2026-06-23 15:09:35,044 12332 sam3_base_predictor.py: 309: propagation ended in session a9f523b6-656c-4117-aaa6-22cb02144a80

# %% [markdown]
# ###  Removing objects
#
# We can remove individual objects using their id.
#
# As an example, let's remove object 2 (which is the dancer in the front).

# %%
# we pick id 2, which is the dancer in the front
obj_id = 0
response = predictor.handle_request(
    request=dict(
        type="remove_object",
        session_id=session_id,
        obj_id=obj_id,
    )
)

# %%
# now we propagate the outputs from frame 0 to the end of the video and collect all outputs
outputs_per_frame = propagate_in_video(predictor, session_id)

# finally, we reformat the outputs for visualization and plot the outputs every 60 frames
outputs_per_frame = prepare_masks_for_visualization(outputs_per_frame)

vis_frame_stride = 60
plt.close("all")
for frame_idx in range(0, len(outputs_per_frame), vis_frame_stride):
    visualize_formatted_frame_output(
        frame_idx,
        video_frames_for_vis,
        outputs_list=[outputs_per_frame],
        titles=["SAM 3 Dense Tracking outputs"],
        figsize=(6, 4),
    )
# Out:
#   0%|          | 0/200 [00:00<?, ?it/s]
# 0it [00:00, ?it/s]
# INFO 2026-06-23 15:10:22,477 12332 sam3_base_predictor.py: 309: propagation ended in session a9f523b6-656c-4117-aaa6-22cb02144a80

# %% [markdown]
# ### Adding new objects with point prompts
#
# We can add new objects through point prompts.
#
# Assuming that we've changed our mind, and now that we want to add back the dancer in the front (whom we just removed in the step above). We can use interactive clicks to add her back.

# %%
sample_img = Image.fromarray(load_frame(video_frames_for_vis[0]))

IMG_WIDTH, IMG_HEIGHT = sample_img.size

# %%
# let's add back the dancer via point prompts.
# we will use a single positive click to add the dancer back.

frame_idx = 0
obj_id = 0
points_abs = np.array(
    [
        [760, 550],  # positive click
    ]
)
# positive clicks have label 1, while negative clicks have label 0
labels = np.array([1])

# %%
# convert points and labels to tensors; also convert to relative coordinates
points_tensor = torch.tensor(
    abs_to_rel_coords(points_abs, IMG_WIDTH, IMG_HEIGHT, coord_type="point"),
    dtype=torch.float32,
)
points_labels_tensor = torch.tensor(labels, dtype=torch.int32)

response = predictor.handle_request(
    request=dict(
        type="add_prompt",
        session_id=session_id,
        frame_index=frame_idx,
        points=points_tensor,
        point_labels=points_labels_tensor,
        obj_id=obj_id,
    )
)
out = response["outputs"]

plt.close("all")
visualize_formatted_frame_output(
    frame_idx,
    video_frames_for_vis,
    outputs_list=[prepare_masks_for_visualization({frame_idx: out})],
    titles=["SAM 3 Dense Tracking outputs"],
    figsize=(6, 4),
    points_list=[points_abs],
    points_labels_list=[labels],
)

# %%
# now we propagate the outputs from frame 0 to the end of the video and collect all outputs
outputs_per_frame = propagate_in_video(predictor, session_id)

# finally, we reformat the outputs for visualization and plot the outputs every 60 frames
outputs_per_frame = prepare_masks_for_visualization(outputs_per_frame)

vis_frame_stride = 60
plt.close("all")
for frame_idx in range(0, len(outputs_per_frame), vis_frame_stride):
    visualize_formatted_frame_output(
        frame_idx,
        video_frames_for_vis,
        outputs_list=[outputs_per_frame],
        titles=["SAM 3 Dense Tracking outputs"],
        figsize=(6, 4),
    )
# Out:
#   0%|          | 0/200 [00:00<?, ?it/s]
# INFO 2026-06-23 15:11:38,659 12332 sam3_base_predictor.py: 309: propagation ended in session a9f523b6-656c-4117-aaa6-22cb02144a80
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[18], line 2
#       1 # now we propagate the outputs from frame 0 to the end of the video and collect all outputs
# ----> 2 outputs_per_frame = propagate_in_video(predictor, session_id)
#       3
#       4 # finally, we reformat the outputs for visualization and plot the outputs every 60 frames
#       5 outputs_per_frame = prepare_masks_for_visualization(outputs_per_frame)
#
# Cell In[6], line 22, in propagate_in_video(predictor, session_id)
#      19 def propagate_in_video(predictor, session_id):
#      20     # we will just propagate from frame 0 to the end of the video
#      21     outputs_per_frame = {}
# ---> 22     for response in predictor.handle_stream_request(
#      23         request=dict(
#      24             type="propagate_in_video",
#      25             session_id=session_id,
#
# File c:\Users\ait44\anaconda3\envs\sam3\Lib\site-packages\torch\utils\_contextlib.py:61, in _wrap_generator.<locals>.generator_context(*args, **kwargs)
#      58         else:
#      59             # Pass the last request to the generator and get its response
#      60             with ctx_factory():
# ---> 61                 response = gen.send(request)
#      63 # We let the exceptions raised above by the generator's `.throw` or
#      64 # `.send` methods bubble up to our caller, except for StopIteration
#      65 except StopIteration as e:
#      66     # The generator informed us that it is done: take whatever its
#      67     # returned value (if any) was and indicate that we're done too
#      68     # by returning it (see docs for python's return-statement).
#
# File ~\sam3\sam3\model\sam3_video_predictor.py:178, in Sam3VideoPredictorMultiGPU.handle_stream_request(self, request)
#     175     for rank in range(1, self.world_size):
#     176         self.command_queues[rank].put((request, True))
# --> 178 yield from super().handle_stream_request(request)
#     180 if self.world_size > 1:
#     181     torch.distributed.barrier()
#
# File c:\Users\ait44\anaconda3\envs\sam3\Lib\site-packages\torch\utils\_contextlib.py:61, in _wrap_generator.<locals>.generator_context(*args, **kwargs)
#      58         else:
#      59             # Pass the last request to the generator and get its response
#      60             with ctx_factory():
# ---> 61                 response = gen.send(request)
#      63 # We let the exceptions raised above by the generator's `.throw` or
#      64 # `.send` methods bubble up to our caller, except for StopIteration
#      65 except StopIteration as e:
#      66     # The generator informed us that it is done: take whatever its
#      67     # returned value (if any) was and indicate that we're done too
#      68     # by returning it (see docs for python's return-statement).
#
# File ~\sam3\sam3\model\sam3_base_predictor.py:105, in Sam3BasePredictor.handle_stream_request(self, request)
#     103 request_type = request["type"]
#     104 if request_type == "propagate_in_video":
# --> 105     yield from self.propagate_in_video(
#     106         session_id=request["session_id"],
#     107         propagation_direction=request.get("propagation_direction", "both"),
#     108         start_frame_idx=request.get("start_frame_index", None),
#     109         max_frame_num_to_track=request.get("max_frame_num_to_track", None),
#     110         output_prob_thresh=request.get(
#     111             "output_prob_thresh",
#     112             getattr(self, "default_output_prob_thresh", 0.5),
#     113         ),
#     114     )
#     115 else:
#     116     raise RuntimeError(f"invalid request type: {request_type}")
#
# File ~\sam3\sam3\model\sam3_base_predictor.py:296, in Sam3BasePredictor.propagate_in_video(self, session_id, propagation_direction, start_frame_idx, max_frame_num_to_track, output_prob_thresh, **kwargs)
#     294 # Forward propagation
#     295 if propagation_direction in ["both", "forward"]:
# --> 296     for frame_idx, outputs in self.model.propagate_in_video(
#     297         **propagate_kwargs,
#     298         reverse=False,
#     299     ):
#     300         yield {"frame_index": frame_idx, "outputs": outputs}
#     301 # Backward propagation
#
# File c:\Users\ait44\anaconda3\envs\sam3\Lib\site-packages\torch\utils\_contextlib.py:61, in _wrap_generator.<locals>.generator_context(*args, **kwargs)
#      58         else:
#      59             # Pass the last request to the generator and get its response
#      60             with ctx_factory():
# ---> 61                 response = gen.send(request)
#      63 # We let the exceptions raised above by the generator's `.throw` or
#      64 # `.send` methods bubble up to our caller, except for StopIteration
#      65 except StopIteration as e:
#      66     # The generator informed us that it is done: take whatever its
#      67     # returned value (if any) was and indicate that we're done too
#      68     # by returning it (see docs for python's return-statement).
#
# File ~\sam3\sam3\model\sam3_video_inference.py:1087, in Sam3VideoInferenceWithInstanceInteractivity.propagate_in_video(self, inference_state, start_frame_idx, max_frame_num_to_track, reverse)
#    1084 for frame_idx in tqdm(processing_order):
#    1085     # run Tracker propagation
#    1086     if propagation_type == "propagation_partial":
# -> 1087         self._prepare_backbone_feats(inference_state, frame_idx, reverse)
#    1088         obj_ids_local, low_res_masks_local, tracker_scores_local = (
#    1089             self._propogate_tracker_one_frame_local_gpu(
#    1090                 tracker_states_local,
#    (...)   1094             )
#    1095         )
#    1097         # broadcast refined object tracker scores and masks to all GPUs
#    1098         # handle multiple objects that can be located on different GPUs
#
# File ~\sam3\sam3\model\sam3_video_inference.py:1349, in Sam3VideoInferenceWithInstanceInteractivity._prepare_backbone_feats(self, inference_state, frame_idx, reverse)
#    1343 num_frames = inference_state["num_frames"]
#    1344 geometric_prompt = (
#    1345     inference_state["constants"]["empty_geometric_prompt"]
#    1346     if inference_state["per_frame_geometric_prompt"][frame_idx] is None
#    1347     else inference_state["per_frame_geometric_prompt"][frame_idx]
#    1348 )
# -> 1349 _ = self.run_backbone_and_detection(
#    1350     frame_idx=frame_idx,
#    1351     num_frames=num_frames,
#    1352     input_batch=input_batch,
#    1353     geometric_prompt=geometric_prompt,
#    1354     feature_cache=feature_cache,
#    1355     reverse=reverse,
#    1356     allow_new_detections=True,
#    1357 )
#
# File ~\sam3\sam3\model\sam3_video_base.py:568, in Sam3VideoBase.run_backbone_and_detection(self, frame_idx, num_frames, input_batch, geometric_prompt, feature_cache, reverse, allow_new_detections)
#     565 max_frame_num_to_track = tracking_bounds.get("max_frame_num_to_track")
#     566 start_frame_idx = tracking_bounds.get("propagate_in_video_start_frame_idx")
# --> 568 sam3_image_out, _ = self.detector.forward_video_grounding_multigpu(
#     569     backbone_out={
#     570         "img_batch_all_stages": input_batch.img_batch,
#     571         **text_outputs,
#     572     },
#     573     find_inputs=input_batch.find_inputs,
#     574     geometric_prompt=geometric_prompt,
#     575     frame_idx=frame_idx,
#     576     num_frames=num_frames,
#     577     multigpu_buffer=feature_cache["multigpu_buffer"],
#     578     track_in_reverse=reverse,
#     579     # also get the SAM2 backbone features
#     580     return_tracker_backbone_feats=True,
#     581     # run NMS as a part of distributed computation
#     582     run_nms=self.det_nms_thresh > 0.0,
#     583     nms_prob_thresh=self.score_threshold_detection,
#     584     nms_iou_thresh=self.det_nms_thresh,
#     585     # pass max_frame_num_to_track to respect tracking limits
#     586     max_frame_num_to_track=max_frame_num_to_track,
#     587     propagate_in_video_start_frame_idx=start_frame_idx,
#     588 )
#     589 # note: detections in `sam3_image_out` has already gone through NMS
#     590 pred_probs = sam3_image_out["pred_logits"].squeeze(-1).sigmoid()
#
# File ~\sam3\sam3\model\sam3_image.py:802, in Sam3ImageOnVideoMultiGPU.forward_video_grounding_multigpu(self, backbone_out, find_inputs, geometric_prompt, frame_idx, num_frames, multigpu_buffer, track_in_reverse, return_sam2_backbone_feats, run_nms, nms_prob_thresh, nms_iou_thresh, **kwargs)
#     800 if frame_idx_next_b is not None and frame_idx_next_b not in multigpu_buffer:
#     801     with torch.profiler.record_function("build_multigpu_buffer_next_chunk2"):
# --> 802         self._build_multigpu_buffer_next_chunk(
#     803             backbone_out=backbone_out,
#     804             find_inputs=find_inputs,
#     805             geometric_prompt=geometric_prompt,
#     806             frame_idx_begin=frame_idx_next_b,
#     807             frame_idx_end=frame_idx_next_e,
#     808             num_frames=num_frames,
#     809             multigpu_buffer=multigpu_buffer,
#     810             run_nms=run_nms,
#     811             nms_prob_thresh=nms_prob_thresh,
#     812             nms_iou_thresh=nms_iou_thresh,
#     813         )
#     815 return out, backbone_out
#
# File ~\sam3\sam3\model\sam3_image.py:835, in Sam3ImageOnVideoMultiGPU._build_multigpu_buffer_next_chunk(self, backbone_out, find_inputs, geometric_prompt, frame_idx_begin, frame_idx_end, num_frames, multigpu_buffer, run_nms, nms_prob_thresh, nms_iou_thresh)
#     833 # `forward_grounding` (from base class `Sam3ImageOnVideo`) runs the detector on a single frame
#     834 with torch.profiler.record_function("forward_grounding"):
# --> 835     out_local = self.forward_grounding(
#     836         backbone_out=backbone_out,
#     837         find_input=find_inputs[frame_idx_local_gpu],
#     838         find_target=None,
#     839         geometric_prompt=geometric_prompt,
#     840     )
#     841 if run_nms:
#     842     with torch.profiler.record_function("nms_masks"):
#     843         # run NMS as a post-processing step on top of the detection outputs
#
# File ~\sam3\sam3\model\sam3_image.py:467, in Sam3Image.forward_grounding(self, backbone_out, find_input, find_target, geometric_prompt, **kwargs)
#     465 # Run the decoder
#     466 with torch.profiler.record_function("SAM3Image._run_decoder"):
# --> 467     out, hs = self._run_decoder(
#     468         memory=out["encoder_hidden_states"],
#     469         pos_embed=encoder_out["pos_embed"],
#     470         src_mask=encoder_out["padding_mask"],
#     471         out=out,
#     472         prompt=prompt,
#     473         prompt_mask=prompt_mask,
#     474         encoder_out=encoder_out,
#     475     )
#     477 # Run segmentation heads
#     478 with torch.profiler.record_function("SAM3Image._run_segmentation_heads"):
#     479     # Apply id_mapping to img_ids if backbone features were recomputed
#
# File ~\sam3\sam3\model\sam3_image.py:268, in Sam3Image._run_decoder(self, pos_embed, memory, src_mask, out, prompt, prompt_mask, encoder_out)
#     264 tgt = query_embed.unsqueeze(1).repeat(1, bs, 1)
#     266 apply_dac = self.transformer.decoder.dac and self.training
#     267 hs, reference_boxes, dec_presence_out, dec_presence_feats = (
# --> 268     self.transformer.decoder(
#     269         tgt=tgt,
#     270         memory=memory,
#     271         memory_key_padding_mask=src_mask,
#     272         pos=pos_embed,
#     273         reference_boxes=None,
#     274         level_start_index=encoder_out["level_start_index"],
#     275         spatial_shapes=encoder_out["spatial_shapes"],
#     276         valid_ratios=encoder_out["valid_ratios"],
#     277         tgt_mask=None,
#     278         memory_text=prompt,
#     279         text_attention_mask=prompt_mask,
#     280         apply_dac=apply_dac,
#     281     )
#     282 )
#     283 hs = hs.transpose(1, 2)  # seq-first to batch-first
#     284 reference_boxes = reference_boxes.transpose(1, 2)  # seq-first to batch-first
#
# File c:\Users\ait44\anaconda3\envs\sam3\Lib\site-packages\torch\nn\modules\module.py:1776, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1774     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775 else:
# -> 1776     return self._call_impl(*args, **kwargs)
#
# File c:\Users\ait44\anaconda3\envs\sam3\Lib\site-packages\torch\nn\modules\module.py:1787, in Module._call_impl(self, *args, **kwargs)
#    1782 # If we don't have any hooks, we want to skip the rest of the logic in
#    1783 # this function, and just call forward.
#    1784 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1785         or _global_backward_pre_hooks or _global_backward_hooks
#    1786         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787     return forward_call(*args, **kwargs)
#    1789 result = None
#    1790 called_always_called_hooks = set()
#
# File ~\sam3\sam3\model\decoder.py:526, in TransformerDecoder.forward(self, tgt, memory, tgt_mask, memory_mask, tgt_key_padding_mask, memory_key_padding_mask, pos, reference_boxes, level_start_index, spatial_shapes, valid_ratios, memory_text, text_attention_mask, apply_dac, is_instance_prompt, decoder_extra_kwargs, obj_roi_memory_feat, obj_roi_memory_mask, box_head_trk)
#     519     assert spatial_shapes.shape[0] == 1, (
#     520         "only single scale support implemented"
#     521     )
#     522     memory_mask = self._get_rpb_matrix(
#     523         reference_boxes,
#     524         (spatial_shapes[0, 0], spatial_shapes[0, 1]),
#     525     )
# --> 526     memory_mask = memory_mask.flatten(0, 1)  # (bs*n_heads, nq, H*W)
#     527 if self.training:
#     528     assert self.use_act_checkpoint, (
#     529         "Activation checkpointing not enabled in the decoder"
#     530     )
#
# KeyboardInterrupt:

# %% [markdown]
# ### Refining an existing object with point prompts
#
# We can also refine the segmentation mask of an existing object through point prompts.
#
# Assuming that we've changed our mind (again) -- for Object ID 2 (the dancer in the front whom we just added back in the step above), now we only want to segment her T-shirt instead of her whole body. We can adjust the segmentation mask with a few more positive and negative clicks.

# %%
# For the dancer in the front, suppose now we only want to segment her T-shirt instead of her whole body
# we will use 2 positive clicks and 2 negative clicks to select her shirt.

frame_idx = 0
obj_id = 2
points_abs = np.array(
    [
        [740, 450],  # positive click
        [760, 630],  # negative click
        [840, 640],  # negative click
        [760, 550],  # positive click
    ]
)
# positive clicks have label 1, while negative clicks have label 0
labels = np.array([1, 0, 0, 1])

# %%
# convert points and labels to tensors; also convert to relative coordinates
points_tensor = torch.tensor(
    abs_to_rel_coords(points_abs, IMG_WIDTH, IMG_HEIGHT, coord_type="point"),
    dtype=torch.float32,
)
points_labels_tensor = torch.tensor(labels, dtype=torch.int32)

response = predictor.handle_request(
    request=dict(
        type="add_prompt",
        session_id=session_id,
        frame_index=frame_idx,
        points=points_tensor,
        point_labels=points_labels_tensor,
        obj_id=obj_id,
    )
)
out = response["outputs"]

plt.close("all")
visualize_formatted_frame_output(
    frame_idx,
    video_frames_for_vis,
    outputs_list=[prepare_masks_for_visualization({frame_idx: out})],
    titles=["SAM 3 Dense Tracking outputs"],
    figsize=(6, 4),
    points_list=[points_abs],
    points_labels_list=[labels],
)

# %%
# now we propagate the outputs from frame 0 to the end of the video and collect all outputs
outputs_per_frame = propagate_in_video(predictor, session_id)

# finally, we reformat the outputs for visualization and plot the outputs every 60 frames
outputs_per_frame = prepare_masks_for_visualization(outputs_per_frame)

vis_frame_stride = 60
plt.close("all")
for frame_idx in range(0, len(outputs_per_frame), vis_frame_stride):
    visualize_formatted_frame_output(
        frame_idx,
        video_frames_for_vis,
        outputs_list=[outputs_per_frame],
        titles=["SAM 3 Dense Tracking outputs"],
        figsize=(6, 4),
    )

# %% [markdown]
# ### Close session
#
# Each session is tied to a single video. We can close the session after inference to free up its resources.
#
# (Then, you may start a new session on another video.)

# %%
# finally, close the inference session to free its GPU resources
# (you may start a new session on another video)
_ = predictor.handle_request(
    request=dict(
        type="close_session",
        session_id=session_id,
    )
)

# %% [markdown]
# ### Clean-up
#
# After all inference is done, we can shutdown the predictor to free up the multi-GPU process group.

# %%
# after all inference is done, we can shutdown the predictor
# to free up the multi-GPU process group
predictor.shutdown()
